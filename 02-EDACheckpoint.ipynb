# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
# - Alice Anderson: Conceptualization, Data curation, Methodology, Writing - original draft
# - Bob Barker:  Analysis, Software, Visualization
# - Charlie Chang: Project administration, Software, Writing - review & editing
# - Dani Delgado: Analysis, Background research, Visualization, Writing - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# How do weather conditions affect the characteristics and severity of collisions involving autonomous vehicles compared to human-driven vehicles in California?
#
# Specifically, we examine whether autonomous vehicles operating in California are involved in different types or severities of collisions than human-driven vehicles under varying weather conditions such as clear weather, rain, fog, and snow. The independent variable is weather condition (clear, rain, fog, snow), the dependent variables are observed collision outcomes (including collision type, damage severity, and whether the vehicle was struck by another party), and the primary comparison variable is vehicle type (autonomous vs. human-driven).
#
# Using California-specific traffic collision datasets, this study applies statistical inference methods to compare collision patterns across weather conditions and vehicle types. Because exposure measures such as miles driven are not available, the analysis focuses on differences in observed collision characteristics rather than true collision rates. By focusing on California, where autonomous vehicle testing and deployment are heavily regulated and documented, we aim to evaluate whether autonomous vehicles exhibit different safety-related collision patterns than human drivers under adverse weather conditions or whether their performance changes under certain environmental factors.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Autonomous vehicles (AVs) are increasingly deployed on public roads, raising important questions about their safety and compliance with traffic laws relative to human-driven vehicles. While much public discussion has focused on whether AVs reduce crash risk, less attention has been paid to how AVs behave with respect to traffic violations, such as speeding, red-light running, or improper lane changes. Weather conditions present a particularly relevant context for this comparison. Rain, fog, and snow degrade visibility and road friction, increasing driving difficulty for humans and simultaneously stressing the perception and control systems used by autonomous vehicles. Understanding how traffic violation rates vary by weather and vehicle type is therefore critical for evaluating whether autonomous vehicles maintain safer or more lawful behavior under adverse conditions.
#
# **CRASH FOCUSED RESEARCH:**
#
# Most existing research comparing autonomous and human-driven vehicles focuses on crash outcomes rather than traffic violations. A recent large-scale matched case–control study published in Nature Communications compared crash involvement between autonomous and human-driven vehicles while controlling for exposure factors such as location and time of day. This study found that AVs exhibited lower crash rates in certain contexts but emphasized that conclusions depend strongly on how exposure and confounding variables are handled.<sup><a href="#fn1" id="ref1">1</a></sup>
#
# ***Limitation:*** However, crash-based analyses face several limitations: crashes are relatively rare events, often underreported or inconsistently categorized, and may not capture everyday rule compliance or near-miss behavior. As noted by the National Highway Traffic Safety Administration (NHTSA), crash datasets are structured around reportable incidents and do not systematically capture non-crash traffic violations or routine enforcement actions.<sup><a href="#fn7" id="ref7">7</a></sup>
#
# Similarly, Kusano et al. analyzed Waymo’s rider-only crash data and compared it to human-driver benchmarks, concluding that AV crash rates were comparable to or lower than human baselines under many conditions, though the authors noted limitations related to operating domains and reporting standards.<sup><a href="#fn2" id="ref2">2</a></sup> These studies establish methodological precedents, such as rate normalization and contextual matching, that are directly relevant for analyzing traffic violation rates, even though violations themselves were not the primary outcome. Because violations occur far more frequently than crashes, analyzing traffic citations may provide a higher-resolution measure of everyday driving behavior and regulatory compliance, particularly in varied environmental conditions.
#
# **WEATHER AND SENSOR RESEARCH:**
#
# A parallel body of work examines how adverse weather conditions affect autonomous vehicle perception and performance, providing insight into mechanisms that may influence traffic violations. Empirical studies of on-road autonomous systems have demonstrated that LiDAR and camera-based detection performance degrades measurably under rain, fog, and snow, leading to reduced object detection range and increased uncertainty.<sup><a href="#fn3" id="ref3">3</a></sup> Comprehensive review articles further document how adverse weather challenges sensor fusion, lane detection, and object tracking, and describe mitigation strategies such as radar integration and weather-robust perception models.<sup><a href="#fn4" id="ref4">4</a></sup> These findings suggest that even if AVs are conservative by design, degraded perception in poor weather may lead to behaviors that increase the likelihood of certain violations (e.g., improper lane positioning or failure to proceed through intersections efficiently).
#
# ***Limitation:*** However, these studies are largely conducted in controlled experimental settings or simulation environments. They typically measure detection range, object classification accuracy, or system disengagement frequency rather than legally defined traffic violations. As the California Department of Motor Vehicles (DMV) notes in its autonomous vehicle disengagement reporting program, disengagements reflect system limitations but do not necessarily indicate illegal driving behavior.<sup><a href="#fn8" id="ref8">8</a></sup> Thus, while perception degradation is documented, its real-world impact on enforceable traffic violations remains understudied.
#
# **ENFORCEMENT AND REPORTING:**
#
# Evidence that autonomous vehicles accumulate real-world traffic citations further motivates direct study of violations rather than crashes alone. In 2024, Waymo vehicles operating in San Francisco received hundreds of traffic tickets, primarily related to parking and obstruction, demonstrating that AVs are subject to, and do incur, formal violations under current enforcement regimes.<sup><a href="#fn5" id="ref5">5</a></sup>
#
# ***Limitation:*** While many of these citations are not moving violations, they highlight that AV behavior can conflict with traffic regulations in practice. Reporting has also noted ambiguity in how law enforcement handles moving violations committed by driverless vehicles, with California introducing new legislation (effective in 2026) to clarify enforcement procedures for autonomous systems.<sup><a href="#fn6" id="ref6">6</a></sup> This regulatory context suggests that violation data may be incomplete or unevenly recorded across vehicle types, an important consideration for statistical inference.
# This regulatory transition creates a methodological challenge - comparisons between AVs and human drivers must account for potential enforcement bias, differences in citation practices, and uneven exposure across geographic regions.
#
# **RESEARCH GAP:**
#
# Finally, existing data infrastructures shape what types of comparative analyses are currently feasible. The National Highway Traffic Safety Administration’s Standing General Order (SGO) requires standardized reporting of crashes involving automated driving systems, providing a structured national dataset for AV safety analysis but excluding non-crash violations.<sup><a href="#fn7" id="ref7">7</a></sup> At the state level, California DMV disengagement reports offer detailed information about AV testing and deployment conditions, which researchers often use to study system limitations and environmental challenges, though these reports do not directly capture violations.<sup><a href="#fn8" id="ref8">8</a></sup> Together, prior work reveals a gap in the literature: while crashes and disengagements have been studied extensively, comparative traffic violation rates across weather conditions and vehicle types remain largely unexplored, motivating the present project.
#
# **This project fills a distinct gap by:**
#
# *   Shifting the outcome variable from crashes to traffic violations (a
# higher-frequency behavioral metric).
# *   Incorporating weather as a central explanatory variable rather than a background control.
# * Using California-specific enforcement data to leverage the state’s unique concentration of AV deployment.
#
# By focusing on violation rates rather than crashes alone, this study provides a complementary perspective on autonomous vehicle safety - one centered on lawful behavior and regulatory compliance in everyday driving contexts, especially under adverse weather conditions.
#
#
# 1. <a name="fn1"></a>Abdel-Aty, M. et al. (2024). A matched case-control analysis of autonomous vs. human-driven vehicle accidents. Nature Communications. https://www.nature.com/articles/s41467-024-48526-4 <a href="#ref1">^</a>
# 2. <a name="fn2"></a>Kusano, K. D. et al. (2024). Comparison of Waymo rider-only crash data to human benchmarks. Traffic Injury Prevention. https://www.tandfonline.com/doi/full/10.1080/15389588.2024.2380786 <a href="#ref2">^</a>
# 3. <a name="fn3"></a>Kim, J. et al. (2023). Empirical analysis of an autonomous vehicle’s LiDAR detection performance under adverse weather. https://pmc.ncbi.nlm.nih.gov/articles/PMC10051412/ <a href="#ref3">^</a>
# 4. <a name="fn4"></a>Xu, C. et al. (2024). A comprehensive review of autonomous driving algorithms. Algorithms (MDPI). https://www.mdpi.com/1999-4893/17/11/526 <a href="#ref4">^</a>
# 5. <a name="fn5"></a>Washington Post (2025). Waymo robotaxis received hundreds of tickets in San Francisco. https://www.washingtonpost.com/technology/2025/03/13/waymo-robotaxis-parking-tickets/ <a href="#ref5">^</a>
# 6. <a name="fn6"></a>Associated Press (2025). Police pull over driverless Waymo as California updates AV enforcement laws. https://apnews.com/article/0a0dffb19bf38c5ee85681a6f83591ff <a href="#ref6">^</a>
# 7. <a name="fn7"></a>National Highway Traffic Safety Administration. Standing General Order on Crash Reporting for Automated Driving Systems. https://www.nhtsa.gov/laws-regulations/standing-general-order-crash-reporting <a href="#ref7">^</a>
# 8. <a name="fn8"></a>California Department of Motor Vehicles. Autonomous Vehicle Disengagement Reports. https://www.dmv.ca.gov/portal/vehicle-industry-services/autonomous-vehicles/disengagement-reports/ <a href="#ref8">^</a>

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that autonomous vehicles will be associated with less severe collision outcomes and more predictable collision patterns than human-driven vehicles under clear and rainy conditions, but that this difference will narrow or potentially reverse under more challenging conditions such as fog or other low-visibility environments. This expectation is based on the idea that autonomous systems excel at rule-based driving and sensor fusion in normal or moderately adverse conditions, enabling consistent braking, lane maintenance, and hazard detection. However, their performance may degrade in difficult environmental conditions due to sensor limitations, such as reduced visibility affecting cameras and lidar systems. In contrast, human drivers may adapt more flexibly to unexpected environmental changes despite generally less consistent driving behavior. Because exposure measures such as miles driven are unavailable, this hypothesis concerns differences in observed collision characteristics and severity rather than true collision rates.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Instructions: REPLACE the contents of this cell with descriptions of your actual datasets.
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name:
#   - Link to the dataset:
#   - Number of observations:
#   - Number of variables:
#   - Description of the variables most relevant to this project
#   - Descriptions of any shortcomings this dataset has with repsect to the project
# - Dataset #2 (if you have more than one!)
#   - same as above
# - etc
#
# Each dataset deserves either a set of bullet points as above or a few sentences if you prefer that method.
#
# If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/xuyimingxym/CA-AV-Collision-Data/main/CA_AV_Collision_2019-2024.csv', 'filename':'CA_AV_Collision.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress: 100%|██████████| 1/1 [00:00<00:00,  5.99it/s]
# Error downloading CA_AV_Collision.csv: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %% [markdown]
# ### Dataset #1
#
# Instructions:
# 1. Change the header from Dataset #1 to something more descriptive of the dataset
# 2. Write a few paragraphs about this dataset. Make sure to cover
#    1. Describe the important metrics, what units they are in, and giv some sense of what they mean.  For example "Fasting blood glucose in units of mg glucose per deciliter of blood.  Normal values for healthy individuals range from 70 to 100 mg/dL.  Values 100-125 are prediabetic and values >125mg/dL indicate diabetes. Values <70 indicate hypoglycemia. Fasting idicates the patient hasn't eaten in the last 8 hours.  If blood glucose is >250 or <50 at any time (regardless of the time of last meal) the patient's life may be in immediate danger"
#    2. If there are any major concerns with the dataset, describe them. For example "Dataset is composed of people who are serious enough about eating healthy that they voluntarily downloaded an app dedicated to tracking their eating patterns. This sample is likely biased because of that self-selection. These people own smartphones and may be healthier and may have more disposable income than the average person.  Those who voluntarily log conscientiously and for long amounts of time are also likely even more interested in health than those who download the app and only log a bit before getting tired of it"
# 3. Use the cell below to
#     1. load the dataset
#     2. make the dataset tidy or demonstrate that it was already tidy
#     3. demonstrate the size of the dataset
#     4. find out how much data is missing, where its missing, and if its missing at random or seems to have any systematic relationships in its missingness
#     5. find and flag any outliers or suspicious entries
#     6. clean the data or demonstrate that it was already clean.  You may choose how to deal with missingness (dropna of fillna... how='any' or 'all') and you should justify your choice in some way
#     7. You will load raw data from `data/00-raw/`, you will (optionally) write intermediate stages of your work to `data/01-interim` and you will write the final fully wrangled version of your data to `data/02-processed`
# 4. Optionally you can also show some summary statistics for variables that you think are important to the project
# 5. Feel free to add more cells here if that's helpful for you

# %%
# =============================================================================
# CALIFORNIA TRAFFIC COLLISION DATA (SWITRS) — DATA WRANGLING
# =============================================================================

# ── 0. IMPORTS & DIRECTORY SETUP ─────────────────────────────────────────────
import os
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from scipy import stats

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 60)
pd.set_option("display.float_format", "{:.2f}".format)

for d in ["data/00-raw", "data/01-interim", "data/02-processed"]:
    os.makedirs(d, exist_ok=True)

print("✓ Directories ready")

# ── 1. LOAD DATASET ───────────────────────────────────────────────────────────

import sqlite3, glob

# Auto-find the sqlite file (works wherever you placed it)
candidates = (
    glob.glob("data/00-raw/*.sqlite") +
    glob.glob("*.sqlite") +
    glob.glob("**/*.sqlite", recursive=True)
)
if not candidates:
    raise FileNotFoundError(
        "switrs.sqlite not found.\n"
        "Download from https://www.kaggle.com/datasets/alexgude/"
        "california-traffic-collision-data-from-switrs\n"
        "and place the .sqlite file in data/00-raw/"
    )

SQLITE_PATH = candidates[0]
print(f"✓ Found SQLite database: {SQLITE_PATH}")

con = sqlite3.connect(SQLITE_PATH)

# Show available tables
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", con)
print(f"  Tables: {tables['name'].tolist()}")

print("\n⏳ Loading collisions table …")
df_raw = pd.read_sql("SELECT * FROM collisions", con)
con.close()

print(f"✓ Dataset loaded — {df_raw.shape[0]:,} rows × {df_raw.shape[1]} columns")

# Save raw snapshot
df_raw.to_parquet("data/00-raw/switrs_raw.parquet", index=False)
print("✓ Raw snapshot saved → data/00-raw/switrs_raw.parquet")

# ── 2. TIDY CHECK ─────────────────────────────────────────────────────────────
print("\n" + "="*60)
print("STEP 2 — TIDY DATA CHECK")
print("="*60)

print("\nFirst 5 rows:")
display(df_raw.head())

print("\nColumn dtypes:")
print(df_raw.dtypes.to_string())

repeated_pattern = [c for c in df_raw.columns
                    if any(c.endswith(str(i)) for i in range(1, 6))]
if repeated_pattern:
    print(f"\n Potential wide-format columns detected: {repeated_pattern}")
else:
    print("\n No wide-format (repeated-measure) columns detected.")
    print("   Each row appears to represent one collision event → data is already tidy.")

# ── 3. DATASET SIZE ───────────────────────────────────────────────────────────
print("\n" + "="*60)
print("STEP 3 — DATASET SIZE")
print("="*60)

n_rows, n_cols = df_raw.shape
mem_mb = df_raw.memory_usage(deep=True).sum() / 1e6
print(f"  Rows        : {n_rows:>12,}")
print(f"  Columns     : {n_cols:>12,}")
print(f"  Memory usage: {mem_mb:>11.1f} MB")

# ── 4. MISSING DATA ANALYSIS ──────────────────────────────────────────────────
print("\n" + "="*60)
print("STEP 4 — MISSING DATA ANALYSIS")
print("="*60)

miss = (
    df_raw.isnull()
    .sum()
    .rename("n_missing")
    .to_frame()
    .assign(pct_missing=lambda x: 100 * x["n_missing"] / n_rows)
    .sort_values("pct_missing", ascending=False)
)
miss_cols = miss[miss["n_missing"] > 0]
print(f"\nColumns with ANY missing values: {len(miss_cols)} / {n_cols}")
print(miss_cols.to_string())

# ── 4a. Visualise missingness ──────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(18, 6))

# Bar: % missing per column (top 30)
top_miss = miss_cols.head(30)
axes[0].barh(top_miss.index[::-1], top_miss["pct_missing"][::-1], color="#d62728")
axes[0].set_xlabel("% Missing")
axes[0].set_title("Top-30 Columns by % Missing")
axes[0].axvline(50, color="gray", linestyle="--", lw=1, label="50%")
axes[0].legend()

# Histogram of % missing across all columns
axes[1].hist(miss["pct_missing"], bins=30, color="#1f77b4", edgecolor="white")
axes[1].set_xlabel("% Missing")
axes[1].set_ylabel("Number of Columns")
axes[1].set_title("Distribution of Missingness Across All Columns")

plt.tight_layout()
plt.savefig("data/01-interim/missingness_overview.png", dpi=120)
plt.show()
print("✓ Saved → data/01-interim/missingness_overview.png")

# ── 4b. Systematic / MAR / MCAR investigation ─────────────────────────────────
print("\n── Systematic missingness investigation ──")

# Define a binary 'has_injury' indicator to test against
if "killed_victims" in df_raw.columns and "injured_victims" in df_raw.columns:
    df_raw["_severe_collision"] = (
        (df_raw["killed_victims"].fillna(0) > 0) |
        (df_raw["injured_victims"].fillna(0) > 0)
    ).astype(int)

    # For top-5 most-missing columns, check missingness rate by severity
    for col in miss_cols.head(5).index:
        miss_by_sev = df_raw.groupby("_severe_collision")[col].apply(
            lambda s: s.isnull().mean() * 100
        ).rename({0: "non-severe", 1: "severe"})
        print(f"\n  '{col}' — % missing by collision severity:")
        print(miss_by_sev.to_string())

# Chi-square test: is road_surface missing more at night?
if "road_surface" in df_raw.columns and "collision_time" in df_raw.columns:
    df_tmp = df_raw[["road_surface", "collision_time"]].copy()
    df_tmp["night"] = pd.to_numeric(df_tmp["collision_time"], errors="coerce").between(2200, 2359) | \
                      pd.to_numeric(df_tmp["collision_time"], errors="coerce").between(0, 559)
    df_tmp["road_surface_missing"] = df_tmp["road_surface"].isnull()
    ct = pd.crosstab(df_tmp["night"], df_tmp["road_surface_missing"])
    chi2, p, *_ = stats.chi2_contingency(ct)
    print(f"\n  Chi-square (road_surface missing ~ night-time): χ²={chi2:.2f}, p={p:.4f}")
    if p < 0.05:
        print("  → Missingness appears NON-RANDOM (MAR): night-time collisions show different missingness rate.")
    else:
        print("  → No significant association detected; missingness may be MCAR for this pairing.")

print("""
Summary interpretation:
  • High-missingness columns (>80%) likely correspond to optional or rarely recorded fields
    (e.g. pedestrian/cyclist details recorded only when present) → MNAR / structurally missing.
  • Medium-missingness columns often associate with collision severity or location type → MAR.
  • Low-missingness columns (<5%) appear essentially MCAR.
""")

# ── 5. OUTLIERS & SUSPICIOUS ENTRIES ─────────────────────────────────────────
print("="*60)
print("STEP 5 — OUTLIERS & SUSPICIOUS ENTRIES")
print("="*60)

# Select numeric columns that make sense to check
num_cols_of_interest = [c for c in [
    "killed_victims", "injured_victims", "party_count",
    "pedestrian_killed_count", "pedestrian_injured_count",
    "bicycle_killed_count", "bicycle_injured_count",
    "motorcycle_killed_count", "motorcycle_injured_count",
] if c in df_raw.columns]

desc = df_raw[num_cols_of_interest].describe(percentiles=[.01,.25,.5,.75,.99]).T
print("\nDescriptive stats (key numeric columns):")
print(desc.to_string())

# Flag rows where killed_victims > 10  (plausible but worth verifying)
if "killed_victims" in df_raw.columns:
    extreme = df_raw[df_raw["killed_victims"] > 10]
    print(f"\n  Rows with killed_victims > 10 : {len(extreme):,}")
    if len(extreme):
        print(extreme[["case_id","collision_date","killed_victims","injured_victims"]].head(10))

# IQR-based outlier count per numeric column
print("\n  IQR-based outlier counts (>Q3+3×IQR or <Q1-3×IQR):")
for col in num_cols_of_interest:
    s = df_raw[col].dropna()
    Q1, Q3 = s.quantile(0.25), s.quantile(0.75)
    IQR = Q3 - Q1
    n_out = ((s < Q1 - 3*IQR) | (s > Q3 + 3*IQR)).sum()
    if n_out:
        print(f"    {col:<40s}: {n_out:>6,} outliers  (max={s.max():.0f})")

# Date sanity check
if "collision_date" in df_raw.columns:
    df_raw["_cdate"] = pd.to_datetime(df_raw["collision_date"], errors="coerce")
    future = df_raw[df_raw["_cdate"] > pd.Timestamp.today()]
    bad_date = df_raw[df_raw["_cdate"] < pd.Timestamp("1960-01-01")]
    print(f"\n  Dates in the future          : {len(future):,}")
    print(f"  Dates before 1960            : {len(bad_date):,}")

# Boxplots
fig, axes = plt.subplots(1, min(4, len(num_cols_of_interest)), figsize=(16, 4))
for ax, col in zip(axes, num_cols_of_interest[:4]):
    ax.boxplot(df_raw[col].dropna(), vert=True, patch_artist=True,
               boxprops=dict(facecolor="#aec7e8"))
    ax.set_title(col, fontsize=9)
    ax.set_ylabel("Count")
plt.suptitle("Outlier Check — Key Count Variables", y=1.02)
plt.tight_layout()
plt.savefig("data/01-interim/outlier_boxplots.png", dpi=120)
plt.show()
print("✓ Saved → data/01-interim/outlier_boxplots.png")

# ── 6. CLEAN THE DATA ─────────────────────────────────────────────────────────
print("\n" + "="*60)
print("STEP 6 — DATA CLEANING")
print("="*60)

df = df_raw.copy()

# ── 6a. Drop structurally/entirely missing columns (>90% missing) ──────────────
THRESHOLD_DROP_COL = 0.90
cols_to_drop = miss[miss["pct_missing"] >= THRESHOLD_DROP_COL * 100].index.tolist()
print(f"\n  Dropping {len(cols_to_drop)} columns with ≥{int(THRESHOLD_DROP_COL*100)}% missing:")
print("  ", cols_to_drop)
df.drop(columns=cols_to_drop, inplace=True)

# ── 6b. Drop helper columns created during analysis ───────────────────────────
helper_cols = [c for c in df.columns if c.startswith("_")]
df.drop(columns=helper_cols, errors="ignore", inplace=True)

# ── 6c. Fix data types ────────────────────────────────────────────────────────
if "collision_date" in df.columns:
    df["collision_date"] = pd.to_datetime(df["collision_date"], errors="coerce")

if "collision_time" in df.columns:
    df["collision_time"] = pd.to_numeric(df["collision_time"], errors="coerce")

# Downcast float64 → float32 for memory savings
float_cols = df.select_dtypes("float64").columns
df[float_cols] = df[float_cols].astype("float32")

int_cols = df.select_dtypes("int64").columns
df[int_cols] = df[int_cols].astype("int32")

count_cols = [c for c in [
    "killed_victims","injured_victims","party_count",
    "pedestrian_killed_count","pedestrian_injured_count",
    "bicycle_killed_count","bicycle_injured_count",
    "motorcycle_killed_count","motorcycle_injured_count",
] if c in df.columns]

before = len(df)
df[count_cols] = df[count_cols].fillna(0)
df.dropna(how="all", inplace=True)
after = len(df)
print(f"\n  dropna(how='all') removed  : {before - after:,} fully-null rows")
print(f"  Count columns filled w/ 0  : {count_cols}")
print(f"  Remaining rows             : {after:,}")

# ── 6e. Remove impossible dates ───────────────────────────────────────────────
if "collision_date" in df.columns:
    before = len(df)
    df = df[(df["collision_date"] >= "1960-01-01") &
            (df["collision_date"] <= pd.Timestamp.today())]
    print(f"\n  Date-range filter removed  : {before - len(df):,} rows")

# ── 6f. Final shape ───────────────────────────────────────────────────────────
print(f"\nFinal cleaned dataset: {df.shape[0]:,} rows × {df.shape[1]} columns")
miss_after = df.isnull().sum().sum()
print(f"Remaining NaN cells: {miss_after:,}")

# Save interim cleaned file
df.to_parquet("data/01-interim/switrs_interim.parquet", index=False)
print("✓ Interim file saved → data/01-interim/switrs_interim.parquet")

# ── 7. WRITE PROCESSED OUTPUT ─────────────────────────────────────────────────
print("\n" + "="*60)
print("STEP 7 — WRITING PROCESSED FILE")
print("="*60)

df.to_parquet("data/02-processed/switrs_clean.parquet", index=False)
print(f"✓ Processed file saved → data/02-processed/switrs_clean.parquet")
print(f"  Rows: {len(df):,}  |  Columns: {df.shape[1]}  "
      f"|  Size: {df.memory_usage(deep=True).sum()/1e6:.1f} MB")

# ── 8. SUMMARY STATISTICS (KEY VARIABLES) ─────────────────────────────────────
print("\n" + "="*60)
print("STEP 8 — SUMMARY STATISTICS (KEY VARIABLES)")
print("="*60)

# Collision severity distribution
if "collision_severity" in df.columns:
    print("\nCollision Severity:")
    print(df["collision_severity"].value_counts(dropna=False).to_string())

# Year-over-year collision counts
if "collision_date" in df.columns:
    df["year"] = df["collision_date"].dt.year
    yearly = df.groupby("year").size().rename("collisions")
    print("\nCollisions per Year:")
    print(yearly.to_string())

    fig, ax = plt.subplots(figsize=(12, 4))
    yearly.plot(kind="bar", ax=ax, color="#1f77b4", edgecolor="white")
    ax.set_title("Annual Collision Count — California (SWITRS)")
    ax.set_xlabel("Year")
    ax.set_ylabel("Number of Collisions")
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{int(x):,}"))
    plt.tight_layout()
    plt.savefig("data/01-interim/yearly_collisions.png", dpi=120)
    plt.show()
    print("✓ Saved → data/01-interim/yearly_collisions.png")

# Fatality stats
if "killed_victims" in df.columns:
    total_killed = int(df["killed_victims"].sum())
    total_injured = int(df["injured_victims"].sum()) if "injured_victims" in df.columns else None
    print(f"\nTotal killed victims (clean dataset) : {total_killed:,}")
    if total_injured:
        print(f"Total injured victims               : {total_injured:,}")

# Top collision causes / primary collision factor
pcf_col = next((c for c in df.columns if "primary_collision_factor" in c or "pcf" in c.lower()), None)
if pcf_col:
    print(f"\nTop 10 Primary Collision Factors ({pcf_col}):")
    print(df[pcf_col].value_counts().head(10).to_string())

# Hour-of-day distribution
if "collision_time" in df.columns:
    df["hour"] = (df["collision_time"].fillna(0) // 100).astype(int).clip(0, 23)
    hourly = df.groupby("hour").size()
    fig, ax = plt.subplots(figsize=(12, 4))
    hourly.plot(kind="bar", ax=ax, color="#ff7f0e", edgecolor="white")
    ax.set_title("Collisions by Hour of Day")
    ax.set_xlabel("Hour (24-hr)")
    ax.set_ylabel("Count")
    ax.yaxis.set_major_formatter(mticker.FuncFormatter(lambda x, _: f"{int(x):,}"))
    plt.tight_layout()
    plt.savefig("data/01-interim/hourly_collisions.png", dpi=120)
    plt.show()
    print("✓ Saved → data/01-interim/hourly_collisions.png")

print("\n" + "="*60)
print("WRANGLING COMPLETE")
print("="*60)
print(f"""
  data/00-raw/switrs_raw.parquet         ← original download
  data/01-interim/switrs_interim.parquet ← after type-fixing & count fill
  data/02-processed/switrs_clean.parquet ← final clean dataset
""")
# Out:
# ✓ Directories ready
# ✓ Found SQLite database: data/00-raw\switrs.sqlite
#   Tables: ['case_ids', 'collisions', 'victims', 'parties']
#
# ⏳ Loading collisions table …

# %% [markdown]
# ### California DMV Autonomous Vehicle Collision Reports (2019–2024)
#
# **Dataset Name:** CA_AV_Collision_2019-2024.csv
# **Link:** https://github.com/xuyimingxym/CA-AV-Collision-Data
# **Number of observations:** 646
# **Number of variables:** 196 raw → 13 after cleaning
#
# #### Important Metrics
#
# **Weather** is recorded as a categorical variable with seven possible values: Clear, Cloudy, Raining, Snowing, Fog, Other, and Wind. This is the main independent variable in the analysis. The weather condition reflects what was reported at the time of the collision by the AV manufacturer on the DMV form. The distribution is highly imbalanced. About 84% of collisions occurred in clear weather, roughly 11% in cloudy conditions, and about 5% in rain. Fog and "Other" each account for fewer than 1% of cases. There are no recorded collisions in snow or wind conditions. This imbalance is important because most AV testing in California takes place in San Francisco where snow essentially doesn't occur and it is relatively rare for dense fog to occur during testing periods. Thus, the dataset contains very few observations in poor weather categories. Because there are only 5 fog cases and no snow cases at all, we really can't say much about how AVs perform in those conditions. Any conclusions drawn from such tiny (or nonexistent) samples would be weak and should be treated very cautiously.
#
# **Autonomous Mode vs. Conventional Mode** is recorded using two binary columns (Yes or blank) to indicate whether the vehicle's self-driving system was in control at the time of the collision or whether a human safety driver was operating the vehicle. This is the central variable for comparing system-driven behavior to human-driven behavior within the same AV fleet. In this dataset, 358 collisions (55%) occurred while the vehicle was in autonomous mode and 284 (44%) occurred in conventional mode, with 4 records missing this information. The distribution is fairly balanced, which is helpful because it gives us a meaningful number of observations in both conditions. That said, it is important to interpret "conventional mode" correctly. In this context, it does not refer to an average human driver. It refers to a trained safety driver employed by an AV company who is operating a vehicle equipped with autonomous technology. These drivers are typically more experienced, more attentive, and specifically trained for this role. As a result, comparisons between autonomous and conventional mode in this dataset likely underestimate the difference between AV performance and the broader driving population.
#
# **Vehicle Damage** is recorded as a categorical variable with five levels: None, Minor, Moderate, Major, and Unknown. The damage level is reported by the AV company itself, following the DMV damage scale, rather than by an independent appraiser. "Minor" typically refers to cosmetic damage such as scratches or small dents with no structural impact. "Moderate" indicates that some structural components were affected, but the vehicle is still drivable. "Major" reflects significant structural damage and may mean the vehicle is no longer drivable. In this dataset, 73% of collisions resulted in minor damage, 15% in moderate damage, 9% in no damage at all, and only 2.3% in major damage. This distribution suggests that most AV-related collisions are relatively low-speed and low-severity incidents. For the purposes of our research question, damage severity acts as a practical measure of collision intensity. It allows us to examine whether certain conditions, such as adverse weather, are associated with more severe outcomes.
#
# **Type of Collision** is recorded as a categorical variable with eight possible categories: Head-On, Sideswipe, Rear End, Broadside, Hit Object, Overturned, Vehicle/Pedestrian, and Other. This variable captures the physical layout or geometry of the crash. Rear-end collisions are the most common type. They account for 18% of cases from the AV's perspective and 32% from the other vehicle's perspective, which suggests that AVs are often being rear-ended rather than causing the rear-end impact themselves. This matters for the weather analysis because rear-end crashes are closely tied to following distance and braking behavior. In conditions like rain or on slippery roads, stopping distances increase and reaction time becomes more critical.
#
# **Struck by Others** is a binary variable coded as 1 for yes and 0 for no. It indicates whether the AV was hit by another vehicle, rather than the AV striking something else. In this dataset, 84% of collisions involve the AV being the vehicle that was struck. For our research question, this variable helps separate collisions that may be linked to the AV's own driving behavior, which could potentially worsen in adverse weather, from collisions that are primarily the result of human driver behavior under the same conditions.
#
# **Road Surface** is recorded as a categorical variable with four levels: Dry, Wet, Snowy/Icy, and Slippery. It describes the physical condition of the roadway at the time of the collision. Although it is related to the weather variable, it captures something slightly different. For example, the road may still be wet after rainfall has stopped, or it may remain dry during cloudy conditions. This variable complements the weather data by giving us a more precise way to assess how environmental factors influence collision patterns.
#
# **Date of Accident and Time of Accident** are recorded separately as a date string (for example, "6/25/2021") and a time string (for example, "2:52"), along with separate AM/PM indicator columns. The dataset covers incidents from January 2019 through December 2024. Time is relevant because certain weather conditions like fog are more likely at specific times of day, and lighting conditions interact with weather to affect driving difficulty.
#
# **Latitude and Longitude** are recorded in decimal degrees using the WGS84 coordinate system. Latitude ranges from about 32.66 (San Diego) up to 37.84 (northern San Francisco), while longitude ranges from roughly −122.51 to −116.27. The data are heavily concentrated around San Francisco (lat ≈ 37.77, lon ≈ −122.42), reflecting where most AV testing occurs. Location matters because weather patterns vary across regions, and we may need to account for geographic concentration to avoid attributing location-based effects to weather alone.
#
# #### Concerns and Limitations
#
# **Self-reported by AV companies.** Every record comes directly from the autonomous vehicle companies themselves. The company writes the accident summary, decides how severe the damage was, and reports whether the car was in autonomous or conventional mode. There is no outside investigator double-checking these details. AV manufacturers have obvious financial and reputational reasons to frame incidents favorably. So while 84% of collisions are reported as the AV being "struck by others," we should keep in mind that this conclusion is based on the company's own account.
#
# **Extreme geographic concentration.** About 75% of the 646 records come from San Francisco, and nearly all remaining cases are from nearby Bay Area cities. San Francisco has a mild Mediterranean climate — it essentially never snows, dense street-level fog is uncommon, and rainfall is moderate. As a result, the dataset contains almost no observations for the weather conditions most relevant to our research question: snow has 0 records, fog has 5, and rain only 31. Any conclusions about AV performance in adverse weather will be based on very limited evidence, and results will not generalize to regions with harsher climates.
#
# **No human-driver comparison group in this dataset.** This dataset only includes collisions involving autonomous vehicles. To compare AV collision rates to human-driver collision rates across weather conditions, we would need to combine this with a separate human-driver dataset and normalize by exposure (e.g., collisions per million miles driven per weather condition). Without that normalization, raw counts are misleading — more collisions in clear weather doesn't mean clear weather is more dangerous; it means more driving happens when conditions are clear.
#
# **No traffic violation data.** Our research question focuses on violation rates, but this dataset only records collisions, not violations. A collision is just one possible outcome of unsafe driving, and many violations never lead to a crash. We would need to treat collisions as an imperfect proxy for unsafe behavior or find an additional violation-specific dataset.
#
# **"Conventional mode" does not equal a normal human driver.** In this dataset, conventional mode refers to trained safety drivers employed by AV companies, not typical members of the public. These drivers are selected, trained, and monitored for this role. Any differences between autonomous and conventional mode should be interpreted as a controlled comparison between software and trained professionals, not software versus average drivers.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import numpy as np
df = pd.read_csv('data/00-raw/CA_AV_Collision.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# show size 
print("--------------RAW DATASET--------------")
print(f"Dataset Shape: {df.shape}")
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")

display(df.head(10))

# The code of this function is completely generated by Google Gemini from the prompt 
# "can I get code to transform the Weather A 1, Weather A 2, up to Weather G 2 columns to two columns of Weather 1, Weather 2 where their values are now a string of ["Clear", "Cloudy", "Raining", "Snowing", "Fog", "Other", "Wind"]?"
def transform_weather_columns(df):
    """
    Consolidates Weather A-G columns into two columns: Weather 1 and Weather 2.
    """
    weather_mapping = {
    'A': 'Clear',
    'B': 'Cloudy',
    'C': 'Raining',
    'D': 'Snowing',
    'E': 'Fog',
    'F': 'Other',
    'G': 'Wind'
    }
    for suffix in ['1', '2']:
        new_column_name = f'Weather {suffix}'
        # Initialize the new column with None/NaN
        df[new_column_name] = np.nan
        df[new_column_name] = df[new_column_name].astype('object')
        
        for char, label in weather_mapping.items():
            old_col = f'Weather {char} {suffix}'
            
            if old_col in df.columns:
                # Identify rows where this weather condition is marked.
                # We check for common indicators like 1, '1', 'X', or True.
                mask = df[old_col].astype(str).str.lower().isin(['1', '1.0', 'true', 'x', 'yes'])
                
                # Assign the label to the new consolidated column
                df.loc[mask, new_column_name] = label
                
    return df

# The code of this function is completely generated by Google Gemini from the prompt 
# "can I get code to transform the Lighting A 1, Lighting A 2, up to Lighting E 2 columns to two columns of Lighting 1, Lighting 2 where their values are now a string of [Daylight, Dark-Dawn, Dark-Street lights, Dark-No street lights, Dark-Street lights not functioning]?"
def transform_lighting_columns(df):
    """
    Consolidates Lighting A-E columns into two columns: Lighting 1 and Lighting 2.
    """
    lighting_mapping = {
    'A': 'Daylight',
    'B': 'Dark-Dawn',
    'C': 'Dark-Street lights',
    'D': 'Dark-No street lights',
    'E': 'Dark-Street lights not functioning'
    }

    for suffix in ['1', '2']:
        new_column_name = f'Lighting {suffix}'
        
        # Initialize with NaN, but immediately cast to 'object' to allow strings
        df[new_column_name] = np.nan
        df[new_column_name] = df[new_column_name].astype('object')
        
        for char, label in lighting_mapping.items():
            old_col = f'Lighting {char} {suffix}'
            
            if old_col in df.columns:
                # Check for indicators of selection (1, '1', 'X', 'Yes', True)
                mask = df[old_col].astype(str).str.lower().isin(['1', '1.0', 'true', 'x', 'yes'])
                df.loc[mask, new_column_name] = label
                
    return df

# The code of this function is completely generated by Google Gemini from the prompt 
# "consolidate the damage columns to be a single column"
def transform_damage_columns(df):
    """
    Consolidates 'Damage: X' columns into a single 'Damage' column.
    """
    # The new single column to hold the result
    new_column_name = 'Damage'
    
    # Initialize with NaN, but immediately cast to 'object' to allow strings
    df[new_column_name] = np.nan
    df[new_column_name] = df[new_column_name].astype('object')
    
    # Mapping of column name -> target label
    # Based on the headers seen in your image
    damage_mapping = {
        'Damage: Unknown': 'Unknown',
        'Damage: None': 'None',
        'Damage: Minor': 'Minor',
        'Damage: Moderate': 'Moderate',
        'Damage: Major': 'Major'
    }

    for old_col, label in damage_mapping.items():
        if old_col in df.columns:
            # Check for indicators of selection (1, '1', 'X', 'Yes', True)
            # The image shows "Yes" specifically, but we keep the list broad just in case
            mask = df[old_col].astype(str).str.lower().isin(['1', '1.0', 'true', 'x', 'yes'])
            
            # Assign the label (e.g., 'Moderate') to the new consolidated column
            df.loc[mask, new_column_name] = label
            
    return df
# The code of this function is completely generated by Google Gemini from the prompt 
# "can I get code to transform the Type A 1, Type A 2, up to Type H 2 columns to two columns of Type 1, Type 2 where their values are now a string of [Head-on, Side swipe, Rear end, Broadside, Hit object, Overturned, Vehicle/pedestrian, Other]?"
def transform_collision_type_columns(df):
    """
    Consolidates Type A-H columns into two columns: 
    'Collision Type 1' and 'Collision Type 2'.
    """
    
    # Mapping based on the order you provided:
    # A=Head-on, B=Side swipe, C=Rear end, etc.
    collision_mapping = {
        'A': 'Head-on',
        'B': 'Side swipe',
        'C': 'Rear end',
        'D': 'Broadside',
        'E': 'Hit object',
        'F': 'Overturned',
        'G': 'Vehicle/pedestrian',
        'H': 'Other'
    }

    for suffix in ['1', '2']:
        new_column_name = f'Collision Type {suffix}'
        
        # Initialize with NaN, but immediately cast to 'object' to allow strings
        df[new_column_name] = np.nan
        df[new_column_name] = df[new_column_name].astype('object')
        
        for char, label in collision_mapping.items():
            # Matches headers like "Type A 1", "Type B 2" seen in your image
            old_col = f'Type {char} {suffix}'
            
            if old_col in df.columns:
                # Check for indicators of selection (1, '1', 'X', 'Yes', True)
                mask = df[old_col].astype(str).str.lower().isin(['1', '1.0', 'true', 'x', 'yes'])
                
                # Assign the label to the new consolidated column
                df.loc[mask, new_column_name] = label
                
    return df

# The code of this function is completely generated by Google Gemini from the prompt 
# "can I get code to transform the Roadway A 1, Roadway A 2, up to Roadway H 2 columns to two columns of Roadway 1, Roadway 2 where their values are now a string of [Dry, Wet, Snowy-Icy, Slippery]?"
def transform_roadway_columns(df):
    """
    Consolidates Roadway A-D columns into two columns: 
    'Roadway 1' and 'Roadway 2'.
    """
    
    # Mapping based on your provided list:
    # A=Dry, B=Wet, C=Snowy-Icy, D=Slippery
    roadway_mapping = {
        'A': 'Dry',
        'B': 'Wet',
        'C': 'Snowy-Icy',
        'D': 'Slippery'
    }

    for suffix in ['1', '2']:
        new_column_name = f'Roadway {suffix}'
        
        # Initialize with NaN, but immediately cast to 'object' to allow strings
        df[new_column_name] = np.nan
        df[new_column_name] = df[new_column_name].astype('object')
        
        for char, label in roadway_mapping.items():
            # Matches headers like "Roadway A 1", "Roadway B 2"
            old_col = f'Roadway {char} {suffix}'
            
            if old_col in df.columns:
                # Check for indicators of selection (1, '1', 'X', 'Yes', True)
                mask = df[old_col].astype(str).str.lower().isin(['1', '1.0', 'true', 'x', 'yes'])
                
                # Assign the label to the new consolidated column
                df.loc[mask, new_column_name] = label
                
    return df


# The code of this function is completely generated by Google Gemini from the prompt 
# "Consolidate the Autonomous Mode and Conventional Mode columns into one column labeled Autonomous Mode"
def transform_autonomous_mode(df):
    """
    Consolidates 'Autonomous Mode' and 'Conventional Mode' columns into a 
    single boolean 'Autonomous Mode' column.
    Values: True (if Autonomous), False (if Conventional), or NaN (if unknown).
    """
    # Create the new column, initialized as object to allow for True/False/NaN mix
    # We use 'object' instead of 'bool' initially to support NaNs easily
    new_col = 'Autonomous Mode'
    
    # Store the old column names based on your image
    auto_col = 'Autonomous Mode' 
    conv_col = 'Conventional Mode'
    
    # We need a temporary holding spot because 'Autonomous Mode' is also the source name
    temp_col = 'Auto_Mode_Temp'
    df[temp_col] = np.nan
    df[temp_col] = df[temp_col].astype('object')

    # 1. Mark as False if Conventional Mode is selected
    if conv_col in df.columns:
        mask_conv = df[conv_col].astype(str).str.lower().isin(['1', '1.0', 'true', 'x', 'yes'])
        df.loc[mask_conv, temp_col] = False

    # 2. Mark as True if Autonomous Mode is selected
    # Note: We do this second so it overwrites Conventional if both are somehow checked 
    # (or you can flip this order depending on which one you trust more)
    if auto_col in df.columns:
        mask_auto = df[auto_col].astype(str).str.lower().isin(['1', '1.0', 'true', 'x', 'yes'])
        df.loc[mask_auto, temp_col] = True

    # Drop the old 'Conventional Mode'
    if conv_col in df.columns:
        df.drop(columns=[conv_col], inplace=True)
        
    # The old 'Autonomous Mode' column still exists, so we drop it before renaming our temp column
    # (unless we want to overwrite it directly, but this is cleaner)
    if auto_col in df.columns:
        df.drop(columns=[auto_col], inplace=True)
        
    # Rename temp column to final name
    df.rename(columns={temp_col: new_col}, inplace=True)

    return df


# The code of this function is completely generated by Google Gemini from the prompt 
# "Using the columns 'Time Of Accident', 'AM', and 'PM', create a new column in 24 hours format"
def transform_time_of_accident(df):
    """
    Consolidates 'Time Of Accident', 'AM', and 'PM' into a single 
    24-hour format 'Time Of Accident' column.
    """
    # Define column names
    time_col = 'Time Of Accident'
    am_col = 'AM'
    pm_col = 'PM'
    
    # Check if required columns exist
    if time_col not in df.columns:
        return df

    # Create a temporary 'Period' column to hold 'AM' or 'PM'
    # We initialize with empty strings or NaNs
    df['_temp_period'] = np.nan
    df['_temp_period'] = df['_temp_period'].astype('object')
    
    # 1. Identify AM rows
    if am_col in df.columns:
        mask_am = df[am_col].astype(str).str.lower().isin(['1', '1.0', 'true', 'x', 'yes'])
        df.loc[mask_am, '_temp_period'] = 'AM'
        
    # 2. Identify PM rows (Overwrites AM if both are checked, which shouldn't happen)
    if pm_col in df.columns:
        mask_pm = df[pm_col].astype(str).str.lower().isin(['1', '1.0', 'true', 'x', 'yes'])
        df.loc[mask_pm, '_temp_period'] = 'PM'
    
    # 3. Create a combined string (e.g., "6:54 PM")
    # We only do this where we have both a time and a period
    valid_rows = df[time_col].notna() & df['_temp_period'].notna()
    
    combined_time = df.loc[valid_rows, time_col].astype(str) + ' ' + df.loc[valid_rows, '_temp_period']
    
    # 4. Convert to datetime objects and then extract 24-hour string (HH:MM)
    # errors='coerce' will turn unparseable text into NaT (Not a Time)
    df.loc[valid_rows, time_col] = pd.to_datetime(combined_time, format='%I:%M %p', errors='coerce').dt.strftime('%H:%M')
    
    # 5. Clean up helper columns
    df.drop(columns=['_temp_period'], inplace=True)
    if am_col in df.columns:
        df.drop(columns=[am_col], inplace=True)
    if pm_col in df.columns:
        df.drop(columns=[pm_col], inplace=True)
        
    return df

# consolidate columns 
transform_weather_columns(df)
transform_lighting_columns(df)
transform_damage_columns(df)
transform_collision_type_columns(df)
transform_roadway_columns(df)
transform_autonomous_mode(df)
transform_time_of_accident(df)


cleaned_df = df[['Date Of Accident','Time Of Accident','Zip Code','Autonomous Mode',
                 'Latitude','Longitude','Struck by Others','Weather 1','Lighting 1','Damage','Collision Type 1','Collision Type 2',
                 'Roadway 1']]


cleaned_df = cleaned_df.rename(columns={'Weather 1': 'Weather', 'Lighting 1': 'Lighting', 'Roadway 1': 'Road Condition'})

print("\n--------------CLEANED DATASET--------------")
print(f"Dataset Shape: {cleaned_df.shape}")
print(f"Rows: {cleaned_df.shape[0]}")
print(f"Columns: {cleaned_df.shape[1]}")

print("\nData Types: ")
print(cleaned_df.dtypes)

cleaned_df.head(10)
# Out:
# --------------RAW DATASET--------------
# Dataset Shape: (646, 196)
# Rows: 646
# Columns: 196
#    Unnamed: 0     Manufacturers Name          Business Name Date Of Accident  \
# 0           0          GM Cruise LLC                 Cruise         1/7/2019
# 1           1  Aurora Innovation Inc  Aurora Innovation Inc        1/10/2019
# 2           2          GM Cruise LLC                 Cruise        1/10/2019
# 3           3              Waymo LLC              Waymo LLC        1/26/2019
# 4           4              Waymo LLC              Waymo LLC         2/6/2019
# 5           5              Waymo LLC              Waymo LLC        2/10/2019
# 6           6          GM Cruise LLC                 Cruise        2/14/2019
# 7           7              Waymo LLC              Waymo LLC        2/26/2019
# 8           8          GM Cruise LLC                 Cruise        2/27/2019
# 9           9             Lyft, Inc.             Lyft, Inc.        2/28/2019
#
# ...

# %%
print("MISSING DATA PER COLUMN")
print("=" * 50)
miss = cleaned_df.isnull().sum()
miss_pct = (miss / len(cleaned_df) * 100).round(1)
miss_df = pd.DataFrame({'Missing': miss, 'Pct': miss_pct}).sort_values('Pct', ascending=False)
print(miss_df.to_string())


# Is the missingness systematic or random?
print("\n\nIS MISSINGNESS SYSTEMATIC?")
print("=" * 50)
print("\nCollision Type 1 missingness by Autonomous Mode:")
ct1_by_mode = cleaned_df.groupby('Autonomous Mode')['Collision Type 1'].apply(lambda x: x.isnull().sum())
ct1_total = cleaned_df.groupby('Autonomous Mode')['Collision Type 1'].size()
print(pd.DataFrame({'Missing': ct1_by_mode, 'Total': ct1_total, 'Pct Missing': (ct1_by_mode/ct1_total*100).round(1)}))


print("\nRoad Condition missingness by Weather:")
rc_by_w = cleaned_df.groupby('Weather')['Road Condition'].apply(lambda x: x.isnull().sum())
rc_total = cleaned_df.groupby('Weather')['Road Condition'].size()
print(pd.DataFrame({'Missing': rc_by_w, 'Total': rc_total, 'Pct Missing': (rc_by_w/rc_total*100).round(1)}))


print("\nConclusion: Collision Type 1 is ~48% missing - this is NOT random.")
print("It reflects that DMV forms often only record collision type from one")
print("vehicle's perspective. Other columns have <5% missing, roughly uniform")
print("across weather conditions and modes - appears missing at random.")


# E. Outliers and Suspicious Entries
print("OUTLIERS AND SUSPICIOUS ENTRIES")
print("=" * 50)


# Geographic outliers
print("\n1. LATITUDE OUTLIERS (most data is SF Bay Area, lat ~37.3-37.9)")
outliers = cleaned_df[(cleaned_df['Latitude'] < 33) | (cleaned_df['Latitude'] > 39)]
print(f"   Records outside lat 33-39: {len(outliers)}")
if len(outliers) > 0:
    print(outliers[['Date Of Accident', 'Latitude', 'Longitude', 'Zip Code']])
print("   (These are San Diego area — legitimate, not errors)")


# Weather imbalance flag
print("\n2. WEATHER SAMPLE SIZE WARNING")
print(cleaned_df['Weather'].value_counts(dropna=False).to_string())
print("   Snow: 0 records, Fog: 5 records, Rain: 31 records")
print("   This is a major limitation for our research question")


# Missing autonomous mode
print(f"\n3. MISSING AUTONOMOUS MODE: {cleaned_df['Autonomous Mode'].isnull().sum()} records")
print("   These rows don't specify if vehicle was in autonomous or conventional mode")


# Damage check
print("\n4. DAMAGE DISTRIBUTION")
print(cleaned_df['Damage'].value_counts(dropna=False).to_string())


# F. Handle Missingness
print("CLEANING STRATEGY")
print("=" * 50)
print("Using dropna on ONLY critical columns: Weather, Autonomous Mode, Lighting, Damage")
print("NOT dropping based on Collision Type (48% missing — would lose half the data)")
print()


required = ['Weather', 'Autonomous Mode', 'Lighting', 'Damage']
print(f"Before: {len(cleaned_df)} rows")


final_df = cleaned_df.dropna(subset=required, how='any').copy()


print(f"After:  {len(final_df)} rows")
print(f"Dropped: {len(cleaned_df) - len(final_df)} rows")


print(f"\nJustification: We only drop rows missing variables essential to our")
print(f"research question (weather × autonomous mode). Dropping on ALL columns")
print(f"would remove ~48% of data because Collision Type 1 is often blank —")
print(f"that's too costly with only 646 records. The Collision Type missingness")
print(f"is structural (DMV forms don't always fill both), not data quality issues.")


print(f"\nRemaining missingness:")
remaining = final_df.isnull().sum()
print(remaining[remaining > 0].to_string())

final_df['Autonomous Mode'] = final_df['Autonomous Mode'].astype(bool)
final_df['Autonomous Mode'] = final_df['Autonomous Mode'].map({True: 'True', False: 'False'})

# G. Save to processed
final_df.to_csv('data/02-processed/CA_AV_Collision_cleaned.csv', index=False)
print(f"Saved to data/02-processed/CA_AV_Collision_cleaned.csv")
print(f"Final shape: {final_df.shape}")
# Out:
# MISSING DATA PER COLUMN
# ...
#                   Missing   Pct
# Collision Type 1      310  48.0
# Collision Type 2      126  19.5
# Road Condition         28   4.3
# Lighting                4   0.6
# Autonomous Mode         4   0.6
# Weather                 4   0.6
# Zip Code                3   0.5
# Time Of Accident        2   0.3
# Damage                  2   0.3
# Latitude                0   0.0
# Date Of Accident        0   0.0
# Longitude               0   0.0
# Struck by Others        0   0.0
#
#
# IS MISSINGNESS SYSTEMATIC?
# ...
#
# Collision Type 1 missingness by Autonomous Mode:
#                  Missing  Total  Pct Missing
# Autonomous Mode
# False                107    284         37.7
# True                 199    358         55.6
#
# Road Condition missingness by Weather:
#          Missing  Total  Pct Missing
# Weather
# Clear         24    542          4.4
# Cloudy         1     63          1.6
# Fog            0      5          0.0
# Other          0      1          0.0
# ...

# %% [markdown]
# ## Dataset #2 — California Traffic Collision Data (SWITRS)
#
# **Dataset Name:** California Traffic Collision Data from SWITRS
# **Link to the dataset:** https://www.kaggle.com/datasets/alexgude/california-traffic-collision-data-from-switrs
# **Number of observations:** ~600–1,000 (depending on version/year range)
# **Number of variables:** ~15–30 (varies by release)
#
# ### Description of variables most relevant to this project
#
# - Vehicle type (autonomous mode vs. manual)
# - Date and time of collision
# - Location (city, county, latitude, longitude)
# - Weather condition
# - Road conditions
# - Collision description
# - Manufacturer / AV system
#
# ### Shortcomings with respect to the project
#
# - Contains only collisions, not all traffic violations
# - Limited geographic scope (California only)
# - AV deployments are concentrated in specific cities
# - Possible reporting inconsistencies across manufacturers
#
# ---
#
# ## Important Metrics
#
# **Weather Condition**
# Weather is recorded as a categorical variable describing environmental conditions at the time of the collision (e.g., clear, rain, fog, snow). This variable is central to the research question because it allows comparison of collision patterns under different driving conditions. However, severe weather categories such as snow occur infrequently in California, which may limit statistical power for those conditions.
#
# **Road Surface Condition**
# Road surface is typically categorized as dry, wet, snowy/icy, or slippery. This variable complements weather data by capturing residual effects of precipitation (e.g., wet roads after rain has stopped). Road surface conditions are directly related to braking distance and vehicle control, making them important indicators of driving difficulty.
#
# **Collision Severity**
# Severity is measured through indicators such as number of fatalities, number of injuries, or severity categories (e.g., property damage only vs. injury collisions). This metric provides insight into the seriousness of crashes and may reflect how dangerous conditions are under different weather scenarios.
#
# **Number of Victims (Injured/Killed)**
# Counts of injured and killed individuals quantify the human impact of collisions. These variables allow analysis beyond simple crash frequency and can indicate whether adverse weather leads to more severe outcomes.
#
# **Primary Collision Factor**
# This variable records the main cause attributed by investigating officers (e.g., speeding, unsafe turning, failure to yield). It serves as a proxy for unsafe driving behavior and helps distinguish collisions caused by driver actions from those primarily due to environmental factors.
#
# **Date and Time of Collision**
# Temporal variables enable analysis of time-of-day effects, seasonal trends, and correlations between weather conditions and traffic density.
#
# **Location (Latitude, Longitude, County)**
# Geographic variables allow spatial analysis and control for regional differences. Weather patterns vary significantly across California, from coastal fog to inland heat and mountain snow.
#
# **Number of Vehicles Involved**
# This variable indicates collision complexity. Multi-vehicle crashes may be more common under poor visibility or slippery conditions.
#
# ---
#
# ## Concerns and Limitations
#
# *Represents collisions only, not all violations**
# The SWITRS dataset records only incidents that resulted in reported crashes. Traffic violations that did not lead to collisions are not included, meaning the dataset may underestimate risky driving behavior.
#
# **Underreporting of minor incidents**
# Property-damage-only collisions or minor incidents may not always be reported to police, leading to bias toward more severe crashes.
#
# **Human-driver dataset is not perfectly comparable to AV dataset**
# SWITRS reflects typical drivers, while the AV dataset includes autonomous operation and trained safety drivers. Differences in driver populations and operating conditions may confound comparisons.
#
# **Geographic and environmental variation**
# California includes diverse climates, but severe weather occurs mainly in specific regions. Most collisions occur in urban areas with mild weather.
#
# **Exposure not measured**
# The dataset does not include miles driven or traffic volume. Higher collision counts in clear weather may reflect more driving rather than greater risk.
#
# **Potential reporting inconsistencies**
# Data are collected across multiple jurisdictions, which may use slightly different reporting standards.
#
# **Missing or incomplete data**
# Some variables may contain missing values or ambiguous entries.
#
# **No direct indicator of autonomous vehicles**
# The dataset does not explicitly identify whether a vehicle was autonomous, so it primarily represents human-driven traffic conditions.

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# #### Section 1 of EDA - Exploring Accident Distributions in Autonomous vs. Traditional Vehicles

# %% [markdown]
# We want to check the proportion of weather incidents for both autonomous and nonautonomous accidents to see whether it enables a difference. From the chart below, we can see that both autonomous and nonautonomous vehicles have the same proportion of accidents in clear weather, which tells us that the there may not be a significant advantage in clear conditions.
#
#
# However, we can see that autonomous vehicles have less incidents in the weather category of "Cloudy", and more in the weather category of "Raining". This may be a result of the specific sensors being inhibited from rain, such as droplets on cameras and LiDARs seeing noise.

# %%
import seaborn as sns
from matplotlib import pyplot as plt

print(final_df.columns)
print("\n---------------------")
print(final_df['Weather'].value_counts())
print("\n---------------------")
sns.histplot(x='Autonomous Mode',hue='Weather',multiple="fill",data=final_df)
plt.ylabel("Proportion of Weather Incidents")
# Out:
# Index(['Date Of Accident', 'Time Of Accident', 'Zip Code', 'Autonomous Mode',
#        'Latitude', 'Longitude', 'Struck by Others', 'Weather', 'Lighting',
#        'Damage', 'Collision Type 1', 'Collision Type 2', 'Road Condition'],
#       dtype='object')
#
# ---------------------
# Weather
# Clear      541
# Cloudy      63
# Raining     30
# Fog          5
# Other        1
# Name: count, dtype: int64
#
# ---------------------
# Text(0, 0.5, 'Proportion of Weather Incidents')

# %% [markdown]
# Now, we want to see just how severe damages are for autonomous vehicles vs nonautonomous vehicles. However, we want to split this up based on weather because we know previously that weather has an impact on the driving of autonomous vehicles.
#
#
# The damage distribution in clear weather is relatively similar, with autonomous vehicles less collisions of moderate damage and more of minor damage, which may mean that the AV system may have reactions that mitigate damage.
#
# The damage distribution in adverse weather conditions however, shows autonomous vehicles with more major damage, which may mean it reacts worse in conditions that inhibit the sensors.

# %%
# Accident Severity in Adverse Weather
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

x_axis_order = [False, True]
damage_order = ['None', 'Minor', 'Moderate', 'Major']

adverse = final_df[final_df["Weather"].isin(["Cloudy","Fog", "Raining"])]
sns.histplot(
    data=adverse,
    x="Autonomous Mode",
    hue="Damage",
    multiple="fill",
    ax=axes[1],
    palette='deep',  
    hue_order=damage_order,
    discrete=True
)

clear = final_df[final_df["Weather"].isin(["Clear"])]
sns.histplot(
    data=clear,
    x="Autonomous Mode",
    hue="Damage",
    multiple="fill",
    ax=axes[0],
    palette='deep',
    hue_order=damage_order,
    discrete=True
)
axes[0].set_title("Damage Distribution in Clear Weather")
axes[1].set_title("Damage Distribution in Adverse Weather")
axes[0].set_ylabel("Proportion")

plt.tight_layout
plt.show()

# %% [markdown]
# Now we want to visualize distribution of collision types across various weather conditions, which may tell us where an AV's system is struggling. However, we should distinguish between whether the vehicle in question is the source of the accident (struck others), or was not the source (was struck by others).
#
# Doing a 2x2 grid of heatmaps, we can see some intersting trends.
#
# The (Autonomous=True, Struck by Others=1) heatmap shows us that many of the autonomous vehicle incidents are rear ends caused by another party. A possible explanation for this could be that the AV system ha smore cautious driving, which can result in abrupt stops and inconsistent driving patterns, which may confuse human drivers.
#
# The (Autonomous=True, Struck by Others=0) heatmap shows that hitting objects is a common theme when the crash is the fault of an AV, which may be due to AV's swerving to avoid an accident and hitting an object, or the sensors fail and the object it hit was wrongly not seen as a threat.
#
# The (Autonomous=True, Struck by Others=1) heatmap shows that humans are more likely to rear end, liekly due to distractions and split focus.

# %%
# visualize distribution of collision types across various weather conditions
fig, axes = plt.subplots(2, 2, figsize=(16, 10), sharey=True)

configs = [
    ("True", 1, axes[0,0]),
    ("True", 0, axes[0,1]),
    ("False", 1, axes[1,0]),
    ("False", 0, axes[1,1])
]

heatmaps = []

# create all heatmaps first and add to list
for auto, struck, ax in configs:
    subset = final_df[
        (final_df["Autonomous Mode"] == auto) &
        (final_df["Struck by Others"] == struck)
    ]
    
    heat = pd.crosstab(
        subset["Weather"],
        subset["Collision Type 1"],
        normalize="all"
    )
    
    heatmaps.append(heat)

vmax = max(h.values.max() for h in heatmaps)

# plot
for (auto, struck, ax), heat in zip(configs, heatmaps):
    sns.heatmap(
        heat,
        annot=True,
        cmap="Blues",
        ax=ax,
        vmin=0,
        vmax=vmax
    )
    
    ax.set_title(f"Autonomous={auto}, Struck by Others={struck}")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Section 2 of EDA if you need it  - please give it a better title than this
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [ ] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
# > We will strictly avoid collecting any information about individuals in the vehicle at the time since our analysis is about the failure of autonomous vehicles, which should not be attributed to any drivers or passengers. By not including such data in our models, we eliminate the risk of personal data leaks.
#
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [ ] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
# > We can conduct an analysis of zip codes to determine if demographic or economic factors end up correlating with autonomous vehicle performance. Due to variations in road infrastructure such as quality of asphalt and clear lane markings, we should make sure not to attribute the failure of autonomous vehicles to weather alone.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
# > We will have normalization of data to prevent misinforming visualizations, such as looking at the driving trips “per-mile”, making sure that a high number of failures in clear driving is not due to more clear weather driving. Furthermore, we will incorporate correct color palettes that will avoid affecting one’s perception of risk, as well as correct and proper labeling of data.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
# > Any PII will be removed as they are not necessary for determining the performance of autonomous vehicles in various weather conditions.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
# > Yes, we will provide a comprehensive walkthrough of our analysis with code and detailed description of analysis and documentation to show exactly how we got our results.
#
#
# ### D. Modeling
#  - [ ] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
# > We want to ensure that the model is strictly looking at atmospheric conditions rather than location-based proxies that correlate with marginalized communities
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
# > We should verify if possible that certain incident reports in low contrast conditions such as story environments don’t vary significantly based on detecting pedestrians with certain physical characteristics, such as skin tone, which can be harder for certain vision systems to pick up.
#
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [ ] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * Communication: We will use iMessage as our primary form of communication. Team members should respond within 24 hours.
# * Meetings: We will meet twice a week on weekdays. Exact times will be determined based on everyone's availability.
# * Task Tracking: We will use a shared Google Doc to assign tasks and track responsibilities. GitHub Issues will be used for code-related work.
# * Deadlines: All tasks should be completed one to two days before the official deadline to allow time for group review and edits.
# * Tone & Respect: All communication should be respectful and professional. Feedback should be constructive and focused on the work, not the individual.
# * Equal Contribution: All members are expected to contribute equally across all aspects of the project, including research, coding, writing, and editing. Tasks will be divided fairly so that no single person carries the majority of the workload.
# * If You're Struggling: If a team member is struggling or falling behind, they should notify the group as soon as possible so we can redistribute tasks or offer support.
# * Decision-Making: Decisions will be made by majority vote. If a team member does not respond within 24 hours and a decision needs to be made, the remaining members will proceed.
# * Accountability: If a team member is not meeting expectations, we will address it directly with them first through written communication. If there is no improvement within one week, we will escalate the issue to the professor.
# * Conflict Resolution: If disagreements arise, we will discuss them as a group and work toward a solution that everyone can agree on. All discussions will remain respectful and focused on the success of the project.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date | Meeting Time      | Completed Before Meeting                         | Discuss at Meeting                                                                 |
# |-------------|-------------------|--------------------------------------------------|------------------------------------------------------------------------------------|
# | 2/4         | TBD               | Finalize and submit Project Proposal             | Review proposal; start searching for datasets on autonomous vehicles, weather, and traffic violations |
# | 2/9         | TBD               | Find and review potential datasets               | Discuss which datasets to use; assign data cleaning and wrangling tasks to team members |
# | 2/16        | TBD               | Import and clean data                            | Review data wrangling progress; prepare for Checkpoint #1 submission               |
# | 2/18        | TBD               | Submit Checkpoint #1: Data                       | Assign EDA tasks; discuss initial analysis plan                                     |
# | 2/25        | TBD               | Begin EDA; create visualizations                 | Review EDA progress; refine analysis approach                                       |
# | 3/4         | TBD               | Finalize EDA; submit Checkpoint #2: EDA           | Assign final report sections; begin analysis                                        |
# | 3/11        | TBD               | Complete analysis; draft results, conclusion, and discussion | Review and edit full project; begin working on final video                          |
# | 3/16        | TBD               | Finalize report and video                        | Submit Final Project, Final Video, and Team Evaluation Survey                       |
# | 3/18        | Before 11:59 PM   | N/A                                              | Submit Final Project, Final Video, and Team Evaluation Survey                       |

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback
